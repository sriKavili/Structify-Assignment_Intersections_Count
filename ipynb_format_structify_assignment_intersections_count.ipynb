# %%
import numpy as np

def generate_points(start, end, step=0.01):
    points = []  # Keeping track of the generated points
    while start != end:  # We will loop until the start point reaches the end point
        points.append(round(start, 2))  # Next, append the rounded start point to the points list
        start += step  # Incrementing the start point by the step value
        # Using the modulo operation with 2π in this context is a method of normalizing angles or radian measures within the range of a circle.
        # This will help in two things
        # 1) When the current initial value is 6.25, if we add 0.1, It will be 6.35, It will go beyond 2*pi. Which violates the rule. In cases like this, normalization will help.
        # 2) By making every point go through "Normalization", we are making sure that we are accurately executing the circular nature of the problem and ensuring that the
        # algorithm's logic remains consistent and correct, especially as points approach and exceed the 2*pi boundary. Ultimately, in this circular motion the points again comes back
        # to "0th" radian
        start = round(start % (2 * np.pi), 2)  # Ensure the start point wraps around 2*pi and is rounded
    return points  # Return the list of generated and rounded points

def is_valid_combination(s_point, e_point, used_points):
    # Check if the combination of s_point and e_point is valid by ensuring:
    # 1. The absolute difference is at least 0.1 (ensuring minimum distance and non-equality)
    # 2. The e_point is not already used (to prevent re-using points in other chords)
    return abs(s_point - e_point) >= 0.1 and s_point != e_point and e_point not in used_points

def find_intersections_and_chords(initial_value):
    MAX_RADIAN = round(2 * np.pi, 2)  # Define the maximum radian value (2*pi) rounded to 2 decimal places
    # Assuming initial_value is 3.14 (approximately),
    # The function will generate points starting from 3.14 radians, with each subsequent point incremented by 0.01 radians.
    # The ending condition for these points would be 3.14 - 0.01 = 3.13 radians, so points will be generated up to just before reaching 3.13 radians again,
    # ensuring the sequence doesn't loop back to the starting point.
    # If the initial_value were 0.1, points would be generated from 0.1 radians up to just before reaching 2*pi radians, covering the entire circle.
    s1 = generate_points(initial_value, initial_value - 0.01 if initial_value != 0.1 else MAX_RADIAN, 0.01)
    chords = []  # Initialize an empty list to store the chords found
    used_points = set()  # Initialize a set to keep track of used points
    count = 0  # Initialize a counter for the number of intersections found

    for s1_point in s1:  # Iterate over each starting point in s1
        if s1_point in used_points: continue  # Skip the point if it has already been used
        e1_candidates = generate_points(s1_point + 0.01, s1_point, 0.01)  # Generate candidate ending points (e1)

        for e1_point in e1_candidates:  # Iterate over each candidate ending point in e1
            if not is_valid_combination(s1_point, e1_point, used_points): continue  # Check if the combination is valid

            s2_candidates = generate_points(e1_point + 0.01, s1_point, 0.01)  # Generate candidate starting points (s2)
            for s2_point in s2_candidates:  # Iterate over each candidate starting point in s2
                if not is_valid_combination(e1_point, s2_point, used_points): continue  # Check if the combination is valid

                e2_candidates = generate_points(s2_point + 0.01, e1_point, 0.01)  # Generate candidate ending points (e2)
                for e2_point in e2_candidates:  # Iterate over each candidate ending point in e2
                    if not is_valid_combination(s2_point, e2_point, used_points): continue  # Check if the combination is valid

                    # If a valid combination is found, update the used points and increment the count
                    used_points.update([s1_point, e1_point, s2_point, e2_point])
                    count += 1  # Increment the intersection count

                    # Map each point to its label and sort them by their values
                    points_labels = {'s1': s1_point, 's2': s2_point, 'e1': e1_point, 'e2': e2_point}
                    # the key parameter to the left of the = sign in the sorted() function call does not refer to the "key" part of a (key, value) pair in a dictionary.
                    # Instead, it's a named parameter of the sorted() function that specifies a function to be applied to each element in the iterable before making
                    # comparisons for sorting.
                    # The key=lambda x: x[1] part means: "For each element x in items, use x[1] (the second element of x, assuming x is a tuple or list) as the value to
                    # compare when sorting."
                    # The key here is not referring to the "key" part of the (key, value) tuples that are being sorted; it's specifying that the sorting should be based
                    #  on the value obtained from the key function applied to each element.
                    sorted_points_labels = sorted(points_labels.items(), key=lambda x: x[1])
                    sorted_labels, sorted_points = zip(*sorted_points_labels)  # Unzip the sorted pairs

                    # Append the sorted points and their corresponding labels to the chords list
                    chords.append((sorted_points, sorted_labels))

    return count, chords  # Return the total count of intersections and the list of chords

initial_value = 3.07  # Set the initial value for generating points
count, chords = find_intersections_and_chords(initial_value)  # Find intersections and chords
print(f"Total intersections found: {count}")  # Print the total number of intersections found
for sorted_points, labels in chords:  # Iterate over each chord
    print(f"Sorted Points: {sorted_points}, Labels: {labels}")  # Print the sorted points and their labels
# Out:
# Total intersections found: 611
# Sorted Points: (3.07, 3.17, 3.27, 3.37), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.38), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.39), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.4), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.41), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.42), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.43), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.44), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.45), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.46), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.47), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.48), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.49), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.5), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.51), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.52), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.53), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.54), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.55), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.56), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.57), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.58), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.59), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.6), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.61), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.62), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.63), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.64), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.65), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.66), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.67), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.68), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.69), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.7), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.71), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.72), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.73), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.74), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.75), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.76), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.77), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.78), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.79), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.8), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.81), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.82), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.83), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.84), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.85), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.86), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.87), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.88), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.89), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.9), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.91), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.92), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.93), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.94), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.95), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.96), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.97), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.98), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 3.99), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.0), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.01), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.02), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.03), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.04), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.05), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.06), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.07), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.08), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.09), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.1), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.11), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.12), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.13), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.14), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.15), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.16), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.17), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.18), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.19), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.2), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.21), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.22), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.23), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.24), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.25), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.26), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.27), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.28), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.29), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.3), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.31), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.32), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.33), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.34), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.35), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.36), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.37), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.38), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.39), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.4), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.41), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.42), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.43), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.44), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.45), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.46), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.47), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.48), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.49), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.5), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.51), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.52), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.53), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.54), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.55), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.56), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.57), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.58), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.59), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.6), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.61), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.62), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.63), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.64), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.65), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.66), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.67), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.68), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.69), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.7), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.71), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.72), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.73), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.74), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.75), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.76), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.77), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.78), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.79), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.8), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.81), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.82), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.83), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.84), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.85), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.86), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.87), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.88), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.89), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.9), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.91), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.92), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.93), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.94), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.95), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.96), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.97), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.98), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 4.99), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.0), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.01), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.02), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.03), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.04), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.05), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.06), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.07), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.08), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.09), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.1), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.11), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.12), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.13), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.14), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.15), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.16), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.17), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.18), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.19), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.2), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.21), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.22), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.23), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.24), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.25), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.26), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.27), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.28), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.29), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.3), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.31), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.32), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.33), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.34), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.35), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.36), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.37), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.38), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.39), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.4), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.41), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.42), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.43), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.44), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.45), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.46), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.47), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.48), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.49), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.5), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.51), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.52), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.53), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.54), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.55), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.56), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.57), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.58), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.59), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.6), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.61), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.62), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.63), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.64), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.65), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.66), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.67), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.68), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.69), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.7), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.71), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.72), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.73), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.74), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.75), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.76), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.77), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.78), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.79), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.8), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.81), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.82), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.83), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.84), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.85), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.86), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.87), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.88), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.89), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.9), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.91), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.92), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.93), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.94), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.95), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.96), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.97), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.98), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 5.99), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.0), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.01), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.02), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.03), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.04), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.05), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.06), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.07), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.08), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.09), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.1), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.11), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.12), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.13), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.14), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.15), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.16), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.17), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.18), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.19), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.2), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.21), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.22), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.23), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.24), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.25), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.26), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.27), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (3.07, 3.17, 3.27, 6.28), Labels: ('s1', 'e1', 's2', 'e2')
# Sorted Points: (0.01, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.02, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.03, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.04, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.05, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.06, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.07, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.08, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.09, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.1, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.11, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.12, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.13, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.14, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.15, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.16, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.17, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.18, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.19, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.2, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.21, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.22, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.23, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.24, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.25, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.26, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.27, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.28, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.29, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.3, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.31, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.32, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.33, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.34, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.35, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.36, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.37, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.38, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.39, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.4, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.41, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.42, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.43, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.44, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.45, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.46, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.47, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.48, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.49, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.5, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.51, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.52, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.53, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.54, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.55, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.56, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.57, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.58, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.59, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.6, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.61, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.62, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.63, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.64, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.65, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.66, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.67, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.68, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.69, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.7, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.71, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.72, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.73, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.74, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.75, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.76, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.77, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.78, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.79, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.8, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.81, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.82, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.83, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.84, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.85, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.86, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.87, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.88, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.89, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.9, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.91, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.92, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.93, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.94, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.95, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.96, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.97, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.98, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (0.99, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.0, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.01, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.02, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.03, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.04, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.05, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.06, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.07, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.08, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.09, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.1, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.11, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.12, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.13, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.14, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.15, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.16, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.17, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.18, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.19, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.2, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.21, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.22, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.23, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.24, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.25, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.26, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.27, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.28, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.29, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.3, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.31, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.32, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.33, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.34, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.35, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.36, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.37, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.38, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.39, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.4, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.41, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.42, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.43, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.44, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.45, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.46, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.47, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.48, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.49, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.5, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.51, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.52, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.53, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.54, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.55, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.56, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.57, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.58, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.59, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.6, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.61, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.62, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.63, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.64, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.65, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.66, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.67, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.68, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.69, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.7, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.71, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.72, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.73, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.74, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.75, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.76, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.77, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.78, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.79, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.8, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.81, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.82, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.83, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.84, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.85, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.86, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.87, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.88, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.89, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.9, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.91, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.92, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.93, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.94, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.95, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.96, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.97, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.98, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (1.99, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.0, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.01, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.02, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.03, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.04, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.05, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.06, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.07, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.08, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.09, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.1, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.11, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.12, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.13, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.14, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.15, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.16, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.17, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.18, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.19, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.2, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.21, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.22, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.23, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.24, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.25, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.26, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.27, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.28, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.29, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.3, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.31, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.32, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.33, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.34, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.35, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.36, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.37, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.38, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.39, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.4, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.41, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.42, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.43, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.44, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.45, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.46, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.47, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.48, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.49, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.5, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.51, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.52, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.53, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.54, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.55, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.56, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.57, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.58, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.59, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.6, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.61, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.62, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.63, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.64, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.65, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.66, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.67, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.68, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.69, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.7, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.71, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.72, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.73, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.74, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.75, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.76, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.77, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.78, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.79, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.8, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.81, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.82, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.83, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.84, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.85, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.86, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.87, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.88, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.89, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.9, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.91, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.92, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.93, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.94, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.95, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.96, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.97, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.98, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (2.99, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.0, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.01, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.02, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.03, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.04, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.05, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.06, 3.07, 3.17, 3.27), Labels: ('e2', 's1', 'e1', 's2')
# Sorted Points: (3.07, 3.08, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.09, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.1, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.11, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.12, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.13, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.14, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.15, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.16, 3.17, 3.27), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.18, 3.19, 3.29), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.2, 3.21, 3.31), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.22, 3.23, 3.33), Labels: ('s1', 'e2', 'e1', 's2')
# Sorted Points: (3.07, 3.24, 3.25, 3.35), Labels: ('s1', 'e2', 'e1', 's2')
